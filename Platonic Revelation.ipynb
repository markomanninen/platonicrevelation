# %% [markdown]
# # Platonic Revelation
#
# This document scetch introduces the usage of the Isopsephy on the book of Revelation.
#
# This is done partly with Python and Javascript approach so that underlying text manuscript (Textus Receptus) is loaded, indexed by greek characters so that at the end it is possible to find isopsephical values from the book.
#
# Starting point of the research is the fact, that Revelation contains exacly 38 * 1224 characters which will make it possible to divide text to blocks evenly to columns. For example 3 columns times 17 characters times 24 rows per page is used.

# %%
from IPython.display import HTML
import rev

#%install_ext https://raw.githubusercontent.com/minrk/ipython_extensions/master/extensions/disable_autoscroll.py
# %load_ext disable_autoscroll
# Out:
# Retrieving data from local csv copy...
# autoscrolling long output is disabled

# %% [markdown]
# Just to make sure everything works as expected try to find out all words/phrases which isopsephy value matches 144:

# %%
rev.get(144)
# Out:
#          count               span  isopsephy
# result
# ειδενο       1    12:13:3-12:13:4        144
# ειρηκα       1             7:14:2        144
# θειον        1            9:17:39        144
# καιηνεν      1  10:10:13-10:10:15        144
# ρμδ          1              7:4:7        144

# %% [markdown]
# Let's see general statistics of the text source:

# %%
rev.chars.describe()
# Out:
#        chapter_index  character_index   verse_index    word_index
# count   46512.000000     46512.000000  46512.000000  46512.000000
# mean       11.776187         3.490820     10.147876     14.267587
# std         6.541844         2.319746      6.114396      9.113013
# min         1.000000         1.000000      1.000000      1.000000
# 25%         6.000000         2.000000      5.000000      7.000000
# 50%        12.000000         3.000000     10.000000     13.000000
# 75%        18.000000         5.000000     15.000000     20.000000
# max        22.000000        16.000000     29.000000     59.000000

# %% [markdown]
# Now we will print the whle book on block. Using search functionality is is possible to find out occurrences of the isopsephy values from the text realtime. Try 1512 on the search input field for example:

# %%
rev.book(19)
# Out:
# <abnum.abnum.remarkuple.table.table.<locals>.table at 0x10a411a90>

# %%
HTML(open('rev.html', 'r').read())
# Out:
# <style>
#
# table.revtable {
#     font-family: monospace;
#     font-size: 12px;
#     text-transform: uppercase;
#     letter-spacing: 2px;
# }
#
# td span[title] {
#     cursor: pointer;
#     border: 1px solid transparent;
#     padding: 2px 0 1px 2px;
# }
#
# td span[title]:hover, td span.hover {
#     border-color: #999;
#     border-right-color: #ccc;
#     border-bottom-color: #ccc;
#     background-color: #eee;
# }
#
# .rendered_html td, .rendered_html th {
#     border: 1px solid #DADADA;
# }
#
# td span.clicked {
#   border-color: green;
#   border-width: 2px;
# }
#
# td span.hit {
#   border-color: blue;
#   border-width: 2px;
# }
#
# td div.totals {
#     float: right;
#     font-size: 80%
# }
#
# </style>
#
# <script>
#
# $( document ).ready(function() {
#
#   var $hits = $('span#hits');
#
#   $('input#search').on('input', function() {
#
#     $hits.text(0);
#
#     var input_value = parseInt($(this).val() || 0);
#
#     //if (input_value > 0) {
#
# ...

# %% [markdown]
# ## The [MIT](http://choosealicense.com/licenses/mit/) License
#
# Copyright &copy; 2016 Marko Manninen
